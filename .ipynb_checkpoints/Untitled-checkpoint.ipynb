# %%
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# データを用意する
w0 = 1.0                             # 定数
w1 = 1.0                             # 係数1
w2 = 2.0                             # 係数2
x = np.random.uniform(0, 10, 300)    # ノイズを含んだx軸を作成
y = np.random.uniform(0, 10, 300)    # ノイズを含んだy軸を作成
# ノイズを含んだ平面点列データを作成
z = w0 + (w1 * x) + (w2 * y) + np.random.uniform(0, 5, 300)

# ここからグラフ描画
# フォントの種類とサイズを設定する。
plt.rcParams['font.size'] = 14
plt.rcParams['font.family'] = 'Times New Roman'

# グラフの入れ物を用意する。
fig = plt.figure()
ax1 = Axes3D(fig)

# 軸のラベルを設定する。
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_zlabel('z')

# データプロットする。
ax1.scatter3D(x, y, z, label='Dataset')
plt.legend()

# グラフを表示する。
plt.show()
print("推定したい平面")
print("z = %f + %fx + %fy"%(w0,w1,w2))
#plt.close()
# Out:
# 推定したい平面
# z = 1.000000 + 1.000000x + 2.000000y

# %%
#データをインポート
with open("C:/Users/kozo/Documents/PYTHON/Least_squares/XXX_original-38765point_trt.xyz", "r") as f:
    dat = f.readlines()

le = len(dat[0])
x, y, z = np.zeros(le) ,np.zeros(le), np.zeros(le)

for i,li in enumerate(dat):
    li = li.replace(" \n","")
    data = li.split(" ")
    print(data)
    x[i], y[i], z[i] = data[0], data[1]. data[2]
# Out:
# ['0.252000', '-0.088000', '-0.002000']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-1120e331c3fb> in <module>()
#      10     data = li.split(" ")
#      11     print(data)
# ---> 12     x[i], y[i], z[i] = data[0], data[1]. data[2]
#      13
#
# AttributeError: 'str' object has no attribute 'data'

# %%
# フォントの種類とサイズを設定する。
plt.rcParams['font.size'] = 14
plt.rcParams['font.family'] = 'Times New Roman'

# グラフの入れ物を用意する。
fig = plt.figure()
ax1 = Axes3D(fig)

# 軸のラベルを設定する。
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_zlabel('z')

# データプロットする。
ax1.scatter3D(x, y, z, label='Dataset')
plt.legend()

# グラフを表示する。
plt.show()
